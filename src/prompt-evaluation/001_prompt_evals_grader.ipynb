# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse AWS S3 Bucket Name from URI\n\nHere's a solution that extracts the bucket name from an S3 URI:\n\n```python\ndef extract_s3_bucket_name(s3_uri):\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): S3 URI in format s3://bucket-name/path/to/file\n        \n    Returns:\n        str: The bucket name, or None if invalid format\n        \n    Examples:\n        >>> extract_s3_bucket_name(\"s3://my-bucket/path/to/file.txt\")\n        'my-bucket'\n        >>> extract_s3_bucket_name(\"s3://another-bucket/\")\n        'another-bucket'\n    \"\"\"\n    if not s3_uri or not isinstance(s3_uri, str):\n        return None\n    \n    # Remove the s3:// prefix\n    if s3_uri.startswith(\"s3://\"):\n        s3_uri = s3_uri[5:]\n    else:\n        return None\n    \n    # Extract bucket name (everything before the first /)\n    bucket_name = s3_uri.split(\"/\")[0]\n    \n    return bucket_name if bucket_name else None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        \"s3://my-bucket/path/to/file.txt\",\n        \"s3://another-bucket/\",\n        \"s3://bucket-with-dashes/folder/subfolder/file.json\",\n        \"s3://my-bucket\",\n        \"my-bucket/path/to/file.txt\",  # Invalid\n        \"s3://\",  # Invalid\n    ]\n    \n    for uri in test_cases:\n        result = extract_s3_bucket_name(uri)\n        print(f\"{uri:45} -> {result}\")\n```\n\n**Output:**\n```\ns3://my-bucket/path/to/file.txt             -> my-bucket\ns3://another-bucket/                         -> another-bucket\ns3://bucket-with-dashes/folder/subfolder/... -> bucket-with-dashes\ns3://my-bucket                                -> my-bucket\nmy-bucket/path/to/file.txt                   -> None\ns3://                                         -> None\n```\n\n## Alternative Solutions\n\n**Using regex:**\n```python\nimport re\n\ndef extract_s3_bucket_name_regex(s3_uri):\n    \"\"\"Extract bucket name using regex.\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n```\n\n**Using urllib:**\n```python\nfrom urllib.parse import urlparse\n\ndef extract_s3_bucket_name_urlparse(s3_uri):\n    \"\"\"Extract bucket name using urllib.parse.\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc if parsed.scheme == 's3' else None\n```\n\n**Using boto3 (AWS SDK):**\n```python\nfrom urllib.parse import urlparse\n\ndef extract_s3_bucket_from_uri(s3_uri):\n    \"\"\"Extract using boto3 style parsing.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"Invalid S3 URI\")\n    return parsed.netloc\n```\n\nChoose the approach that best fits your use case. The first solution is straightforward and doesn't require additional dependencies.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively solves the stated task with clear, working code and good documentation. However, it has a missed opportunity: the urllib solution is more robust and uses standard library functionality specifically designed for URI parsing. The primary solution lacks AWS bucket name validation, which matters in production code. For a real-world AWS application, either the urllib approach should be primary, or bucket name validation should be added to the string-parsing approach. The alternative solutions are helpful but their relative merit isn't clearly explained."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template Snippet\n\nHere's a JSON CloudFormation template snippet that defines an AWS Lambda function with basic properties:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-lambda-function\",\n        \"Runtime\": \"python3.11\",\n        \"Handler\": \"index.handler\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Code\": {\n          \"ZipFile\": \"def handler(event, context):\\n    return {'statusCode': 200, 'body': 'Hello from Lambda!'}\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n| Property | Description |\n|----------|-------------|\n| **FunctionName** | `my-lambda-function` - Logical name for the Lambda function |\n| **Runtime** | `python3.11` - Runtime environment (alternatives: nodejs18.x, java11, etc.) |\n| **Handler** | `index.handler` - Entry point (file.function_name format) |\n| **Role** | Reference to IAM execution role with Lambda permissions |\n| **Code** | Inline code or reference to S3 bucket |\n\n## Notes:\n\n- The `LambdaExecutionRole` is required for Lambda to execute and has basic CloudWatch Logs permissions\n- `ZipFile` is used for inline code; for larger functions, use `S3Bucket` and `S3Key`\n- Supports multiple runtimes (Python, Node.js, Java, Go, Ruby, C#, etc.)",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda function with basic properties (FunctionName, Runtime, Handler, Role)",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution is technically correct and production-ready, demonstrating strong AWS knowledge by including best practices like proper IAM role setup and CloudWatch Logs permissions. However, it slightly over-delivers on the stated requirements by providing a full template instead of a focused snippet. The documentation is clear and helpful, though it could better explain the distinction between snippet and full template, and clarify that Role accepts ARN strings. The code is valid CloudFormation that would deploy successfully."
#   },
#   {
#     "output": "```python\nimport json\nimport re\n\ndef has_wildcard_in_resource(policy_json_string: str) -> bool:\n    \"\"\"\n    Check if an AWS IAM policy JSON string contains a wildcard (*) in the Resource field.\n    \n    Args:\n        policy_json_string: A JSON string representing an AWS IAM policy\n        \n    Returns:\n        True if the policy contains a wildcard (*) in any Resource field, False otherwise\n        \n    Raises:\n        json.JSONDecodeError: If the input string is not valid JSON\n    \"\"\"\n    try:\n        policy = json.loads(policy_json_string)\n    except json.JSONDecodeError as e:\n        raise json.JSONDecodeError(f\"Invalid JSON: {e.msg}\", e.doc, e.pos)\n    \n    # Get the Statement array\n    statements = policy.get(\"Statement\", [])\n    \n    # If Statement is not a list, make it a list\n    if not isinstance(statements, list):\n        statements = [statements]\n    \n    # Check each statement for wildcard in Resource field\n    for statement in statements:\n        if not isinstance(statement, dict):\n            continue\n            \n        resources = statement.get(\"Resource\", [])\n        \n        # Handle both string and list formats\n        if isinstance(resources, str):\n            resources = [resources]\n        elif not isinstance(resources, list):\n            resources = [resources]\n        \n        # Check if any resource contains a wildcard\n        for resource in resources:\n            if isinstance(resource, str) and \"*\" in resource:\n                return True\n    \n    return False\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: Policy with wildcard in Resource\n    policy_with_wildcard = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::mybucket/*\"\n            }\n        ]\n    }\n    '''\n    print(f\"Test 1 (with wildcard): {has_wildcard_in_resource(policy_with_wildcard)}\")  # Should be True\n    \n    # Test 2: Policy without wildcard in Resource\n    policy_without_wildcard = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::mybucket/specific-file.txt\"\n            }\n        ]\n    }\n    '''\n    print(f\"Test 2 (without wildcard): {has_wildcard_in_resource(policy_without_wildcard)}\")  # Should be False\n    \n    # Test 3: Policy with wildcard as entire Resource\n    policy_wildcard_all = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"*\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    '''\n    print(f\"Test 3 (wildcard all): {has_wildcard_in_resource(policy_wildcard_all)}\")  # Should be True\n    \n    # Test 4: Policy with multiple resources, one containing wildcard\n    policy_multiple_resources = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": [\n                    \"arn:aws:s3:::mybucket/file1.txt\",\n                    \"arn:aws:s3:::otherbucket/*\"\n                ]\n            }\n        ]\n    }\n    '''\n    print(f\"Test 4 (multiple resources): {has_wildcard_in_resource(policy_multiple_resources)}\")  # Should be True\n    \n    # Test 5: Policy with multiple statements\n    policy_multiple_statements = '''\n    {\n        \"Version\": \"2012-10-17\",",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy JSON string and returns True if it contains a wildcard (*) in the Resource field",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly implements the core functionality of detecting wildcards in Resource fields and handles various input formats robustly. The logic is sound and the error handling is appropriate. However, the unused import and incomplete test case suggest the code wasn't fully reviewed before submission. The solution would benefit from removing the unused import and completing the test file. While not critical, the lack of IAM policy structure validation means edge cases like missing Statement fields won't be caught, though this wasn't explicitly required by the task."
#   }
# ]
